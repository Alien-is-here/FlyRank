# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Alien-is-here/FlyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Answer:**
#
# I chose Speech Emotion Recognition because human speech contains acoustic characteristics that can indicate emotional states. I want to investigate whether machine learning can classify emotions from speech recordings and understand which audio characteristics are useful for distinguishing different emotions.

# %%
# This cell is for CODE (numbers, a query, a check).

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Answer:** The project aims to improve the decision of identifying the emotion expressed in a speech recording. A speech-based application or system would use the classification result to respond or adapt to the detected emotion. A wrong classification could cause the application to respond inappropriately to the user's emotional state.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# **Answer:**
#
# The TESS dataset contains 5,600 speech recordings across 7 emotion classes, with 800 recordings for each class. The balanced distribution provides sufficient labeled data to investigate whether machine learning can distinguish emotions from speech audio. These characteristics make the dataset suitable for a 7-week investigation of speech emotion classification.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#label_counts = Counter(labels)  # Counts how many recordings belong to each emotion class.

#print("Total recordings:", len(labels))  # Shows the total number of audio recordings.
#print("Number of emotion classes:", len(label_counts))  # Shows how many different emotions/classes exist.
#print("Recordings per class:", dict(label_counts))  # Shows the number of recordings for each emotion.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **Answer:**
#
# This project will measure how well machine learning models classify the emotion labels associated with speech recordings in the TESS dataset. The results can provide observed and measured evidence about classification performance and can support decisions about which audio features or models are useful for speech emotion classification. The project will not prove that a particular acoustic feature causes an emotion, and it will not establish that the model can determine a person's true emotional state outside the dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
