# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Alien-is-here/FlyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Answer:**
#
# I chose **Content Archetype Clustering** because different content items may have different patterns of search performance, engagement, freshness, and other observable characteristics. I want to investigate whether machine learning can group content items into meaningful archetypes based on these characteristics, so that similar types of content can be analyzed and handled together.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Answer:**
#
# The project aims to improve the decision of identifying groups of content items that have similar performance characteristics. A content or SEO team could use these groups to understand which types of content behave similarly and decide where further analysis or action is useful. A wrong grouping could lead to misleading conclusions about a group of pages and result in inappropriate recommendations or wasted effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# **Answer:**
#
# There are 30,000 pages, and they aren't all the same. They have different content types, different search intents, and different measurable characteristics. Therefore, it makes sense to investigate whether they naturally form meaningful groups.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("/content/content_refresh_anonymized.csv")
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %%
df.nunique()
# Out:
# content_id                30000
# client_id                    32
# search_volume                41
# competition                 101
# competition_level             3
# cpc                         915
# content_type                  3
# main_intent                   4
# word_count                 5476
# char_count                14839
# provider_used                 2
# model_used                    5
# impressions_90d            9438
# clicks_90d                  477
# pageviews_90d               856
# sessions_90d                666
# users_90d                   644
# engaged_sessions_90d         68
# ai_sessions_90d              35
# scroll_events_90d           155
# days_with_impressions        88
# days_with_sessions           90
# impressions_last_30d       5182
# clicks_last_30d             239
# sessions_last_30d           359
# impressions_prev_30d       5931
# clicks_prev_30d             258
# sessions_prev_30d           311
# content_age_days            225
# ...

# %%
print("Total content items:", len(df))
print("Number of clients:", df["client_id"].nunique())
print("Content types:", df["content_type"].nunique())
print("Search intents:", df["main_intent"].nunique())
# Out:
# Total content items: 30000
# Number of clients: 32
# Content types: 3
# Search intents: 4

# %%
df.describe(include='object')
# Out:
#                   content_id          client_id competition_level  \
# count                  30000              30000             27390
# unique                 30000                 32                 3
# top     content_6880eb215048  client_19581e27de               LOW
# freq                       1               7008             22896
#
#            content_type    main_intent provider_used              model_used  \
# count             30000          27626          8562                   24267
# unique                3              4             2                       5
# top     keyword article  informational        google  gemini-3-flash-preview
# freq              27207          17235          7364                   13271
#
#        age_tier freshness_tier word_count_tier char_count_tier  \
# count     30000          30000           22301           22301
# unique        4              4               4               4
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                         search_volume  competition       cpc  word_count  \
# search_volume                1.000000     0.049887  0.042085   -0.019458
# competition                  0.049887     1.000000  0.302415   -0.201019
# cpc                          0.042085     0.302415  1.000000   -0.090349
# word_count                  -0.019458    -0.201019 -0.090349    1.000000
# char_count                  -0.023876    -0.185828 -0.082660    0.939252
# impressions_90d              0.001203    -0.053530 -0.025599    0.163345
# clicks_90d                  -0.011260    -0.032160 -0.023418    0.091271
# pageviews_90d               -0.015152    -0.071989 -0.028970    0.359895
# sessions_90d                -0.013171    -0.063738 -0.029505    0.332124
# users_90d                   -0.013394    -0.065026 -0.029417    0.340521
# engaged_sessions_90d        -0.009712    -0.019755 -0.014396    0.134550
# ai_sessions_90d             -0.012218    -0.030091 -0.008520    0.207586
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **Answer:**
#
# This project will group content items that have similar characteristics, such as content and performance metrics. These groups can help us understand different types of content and how they behave. However, the results will not prove that one factor causes another or that the same groups will perform the same way in the future. It also will not prove that a certain type of content will improve search performance or predict how Google ranks pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
