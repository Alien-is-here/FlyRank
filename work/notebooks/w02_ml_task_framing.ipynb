# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Alien-is-here/FlyRank/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# **Answer:**
#
# This is a clustering task because the goal is to group content items that have similar characteristics without using a predefined target label. The groups will be based on observable content and performance features, helping us identify different content archetypes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# **Answer:**
#
# There is no predefined target label for this clustering task. Instead, the model will use selected observable content and performance features to find groups of similar content items. The resulting clusters will be interpreted as possible content archetypes based on the characteristics shared by the items in each group.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# **Answer:**
#
# I will use the Silhouette Score to evaluate the quality of the clusters. A higher score means that content items are generally more similar to the items in their own cluster and more different from items in other clusters. This will help determine whether the identified groups are reasonably well separated.

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# **Answer:**
#
#
# The unit of analysis is one content item. Each row represents one content item with its observable content and performance characteristics.

# %%
import pandas as pd

df=pd.read_csv("/content/content_refresh_anonymized.csv")

df.head()
df.shape
# Out:
# (30000, 44)

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# **Answer:**
#
# A fixed rule would require us to manually decide which characteristics define each type of content. However, content performance can depend on several factors at the same time, and the patterns may not be simple enough for a few if-statements. Clustering can examine multiple features together and identify groups of content items with similar patterns that may not be obvious from individual features.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
